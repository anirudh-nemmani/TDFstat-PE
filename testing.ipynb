# %%
import numpy as np

# %%
import init_arrays

# %%
init_arrays.ArrayInitializer()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 init_arrays.ArrayInitializer()
#
# TypeError: ArrayInitializer.__init__() missing 3 required positional arguments: 'sett', 'opts', and 'aux_arr'

# %%
import constants as cs

omr = cs.C_OMEGA_R*0.5

check = init_arrays.Settings(2**18, 2, omr, 1, 17)

# %%
check.band
# Out:
# 17
